# %%
# !python hw4_step1_main.py
# Out:
# python3: can't open file '/content/hw4_step1_main.py': [Errno 2] No such file or directory

# %%
# !ls -R .
# Out:
# .:
# sample_data
#
# ./sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md
